# %%
import pandas as pd
#df=pd.read_csv(r"C:\Users\kuwon\OneDrive\Desktop\GamingStudy_data.csv")
df=pd.read_excel(r"C:\Users\kuwon\OneDrive\Desktop\Kenny_homework2.xlsx")
#(r"C:\Users\User\Desktop\DAP2022\titanic.csv")
#r"./resources/titanic.csv"
df
# Out:
#             Student Name  Age  Grade  homeroom
# 0       Sarah Ashworth    NaN    NaN       NaN
# 1         Amanda Johnson  NaN    NaN       NaN
# 2            David Cline  NaN    NaN       NaN
# 3        Matthew Roberts  NaN    NaN       NaN
# 4        Sierra Chadwick  NaN    NaN       NaN
# 5    Ronnie Dangerfield,  NaN    NaN       NaN
# 6          Thomas Cruise  NaN    NaN       NaN
# 7   Bradley Swickerwrath  NaN    NaN       NaN
# 8           Gracie Smith  NaN    NaN       NaN
# 9          John McDonald  NaN    NaN       NaN
# 10         Raymond James  NaN    NaN       NaN

# %%
import pandas as pd
station=pd.read_csv(r"C:\Users\kuwon\Downloads\archive\station.csv")
#athletes = pd.read_excel('./resources/sample_winterathletes.xlsx',
#                    sheet_name='Athletes')
station
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[60], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv(r"C:\Users\kuwon\OneDrive\Desktop\GamingStudy_data.csv")
#       3 #athletes = pd.read_excel('./resources/sample_winterathletes.xlsx',
#       4 #                    sheet_name='Athletes')
#       5 df
#
# File c:\Users\kuwon\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\kuwon\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
# ...
